# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('Automobile.csv')

# %%
# df= pd.read_csv('D:\Python_coding\datasets\Automobile.csv') #same as the previous statement

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.relplot(df['engine_size'],df['price'])
# Out:
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot(x='engine_size', y='price',data=df)

# %%
sns.relplot(x='engine_size',y='price',hue='body_style',data= df)

# %%
sns.relplot(x='engine_size',y='price',hue='stroke',data = df)

# %%
sns.relplot(x='engine_size',y='price',size='body_style',data = df)

# %% [markdown]
# ## Plotting Categorical Data

# %% [markdown]
# #### Jitter Plot

# %%
df2=pd.read_csv('Automobile.csv')

# %%
df2.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
sns.catplot(x='fuel_system',y='normalized_losses',data=df2)

# %%
sns.catplot(x='fuel_system',y='normalized_losses',jitter=False,data=df2)

# %% [markdown]
# #### Hue Plot

# %%
sns.catplot(x='fuel_system',y='normalized_losses',hue='number_of_doors',data=df2)

# %%
sns.catplot(x='fuel_system',y='normalized_losses',hue='number_of_doors',kind='swarm',data=df2)
# Out:
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='engine_location',y='normalized_losses',hue='number_of_doors',kind='swarm',data=df2)

# %% [markdown]
# #### Boxplot

# %%
sns.catplot(x='fuel_system',y='normalized_losses',kind='box',data=df2)

# %%
sns.catplot(x='fuel_system',y='normalized_losses',hue='number_of_doors',kind='box',data=df2)

# %% [markdown]
# #### Violin Plot

# %%
sns.catplot(x='fuel_system',y='normalized_losses',hue='number_of_doors',kind='violin',data=df2)

# %%
sns.catplot(x='fuel_system',y='normalized_losses',hue='number_of_doors',kind='violin',split=True,data=df2)

# %% [markdown]
# #### Bar Plot

# %%
sns.catplot(x='fuel_system',y='normalized_losses',hue='number_of_doors',kind='bar',data=df2)

# %% [markdown]
# #### Point Plot

# %%
sns.catplot(x='fuel_system',y='normalized_losses',hue='number_of_doors',kind='point',data=df2)

# %% [markdown]
# #### Swarm Plot

# %%
sns.catplot(x='fuel_system',y='normalized_losses',col='fuel_type',aspect=0.9,hue='number_of_doors',kind='swarm',data=df2)
# Out:
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 7.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Visualizing the Distribution of Dataset

# %% [markdown]
# ### Univariate Distribution

# %% [markdown]
# #### Histogram

# %%
sns.distplot(df2.engine_size)
# Out:
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='engine_size', ylabel='Density'>

# %%
sns.distplot(df2.engine_size,kde=False,rug=True)
# Out:
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\smili\anaconda3\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='engine_size'>

# %% [markdown]
# ### Bivariate Distribution

# %%
sns.jointplot(x='engine_size',y='price',data=df2)

# %% [markdown]
# #### Hexplot

# %%
sns.jointplot(x='engine_size',y='price',kind='hex',data=df2)

# %%
sns.jointplot(x=df2.engine_size,y=df2.price,kind='hex')

# %% [markdown]
# #### KDE Plot

# %%
sns.jointplot(x='engine_size',y='price',kind='kde',data=df2)

# %% [markdown]
# #### Heatmaps

# %%
corrmat=df2.corr()
f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=.8, square=True) # It is only taking  numeric columns from the dataset
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Boxen Plot

# %%
sns.catplot(x='engine_size',y='price',kind='boxen',height=8,aspect=2.7,hue='number_of_doors',data=df2)

# %% [markdown]
# #### Ridge Plot or Joy Plot

# %% [markdown]
# ## Visualizing Pairwise Relationships in a Dataset

# %%
sns.pairplot(df2)
